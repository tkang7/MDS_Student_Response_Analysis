# %%
# !conda install wordcloud --yes
# Out:
# Channels:
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !conda install nltk --yes
# Out:
# Channels:
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !conda install textblob --yes
# Out:
# Channels:
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !conda install transformers --yes
# Out:
# Channels:
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !conda install -c conda-forge tensorflow --yes
# Out:
# Channels:
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !conda install tf-keras --yes
# Out:
# Channels:
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/tkang/miniforge3
#
#   added / updated specs:
#     - tf-keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tf-keras-2.16.0            |     pyhd8ed1ab_0         885 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         885 KB
#
# The following NEW packages will be INSTALLED:
#
#   tf-keras           conda-forge/noarch::tf-keras-2.16.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import textblob
import tensorflow as tf
from wordcloud import WordCloud, ImageColorGenerator
from nltk.sentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
from transformers import pipeline

# %%
url = "block1_academic_student_response.csv"
default_column_names = np.arange(16)
new_column_names = ["timestamp", "q1", "q1_detail", "q2", "q2_detail", "q3", "q3_detail",  "q4", "q4_detail", "q5", "q5_detail", "q6", "q6_detail", "working_detail", "not_working_detail", "other_detail"]
df = pd.read_csv(url, header=None)
df.rename(columns=dict(zip(default_column_names, new_column_names)), inplace=True)
df.head()
# Out:
#             timestamp                                                 q1  \
# 0           Timestamp  Q1: How satisfied are you with the structure o...
# 1  9/21/2024 16:49:35                                            Neutral
# 2  9/21/2024 17:00:18                                       Dissatisfied
# 3  9/21/2024 17:07:21                                            Neutral
# 4  9/21/2024 18:05:19                                       Dissatisfied
#
#                                            q1_detail  \
# 0  If you have anything to share for Q1, please u...
# 1  I'm not a fan of the flipped classroom concept...
# 2                                                NaN
# 3  Week 3 is quite intense. I'm okay the whole st...
# 4  I think the fast paced is not ideal for people...
#
#                                                   q2  \
# 0  Q2. How satisfied are you with the assessment ...
# 1                                     Very satisfied
# 2                                       Dissatisfied
# 3                                            Neutral
# 4                                       Dissatisfied
#
#                                            q2_detail  \
# 0  If you have anything to share for Q2, please u...
# 1                                                NaN
# 2                                                NaN
# 3  For the quiz assessment structure, I don't lik...
# 4  The assessments should be one assessment at th...
#
#                                                   q3  \
# 0  Q3. How satisfied are you with the Instructors...
# 1                                     Very satisfied
# 2                                            Neutral
# 3                                            Neutral
# 4                                            Neutral
#
#                                            q3_detail  \
# 0  If you have anything to share for Q3, please u...
# 1                                                NaN
# 2                                                NaN
# 3  For 521, Andy is too fast and sometimes, I don...
# 4  Instructors can rush through materials but emp...
#
#                                                   q4  \
# 0  Q4. How satisfied are you with the Communicati...
# 1                                     Very satisfied
# 2                                            Neutral
# 3                                          Satisfied
# 4                                            Neutral
#
#                                            q4_detail  \
# 0  If you have anything to share for Q4, please u...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4              Communication through email is great.
#
#                                                   q5  \
# 0  Q5. How challenging has the program been thus ...
# 1                             Moderately Challenging
# 2                              Extremely Challenging
# 3                                   Very Challenging
# 4                              Extremely Challenging
#
#                                            q5_detail  \
# 0  If you have anything to share for Q5, please u...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  I dont have technical background and i find my...
#
#                                                   q6  \
# 0  Q6. How has balancing the course workload been...
# 1                                  Mostly Manageable
# 2                      Extremely difficult to manage
# 3                            Frequently Overwhelming
# 4                            Frequently Overwhelming
#
#                                            q6_detail  \
# 0  If you have anything to share for Q6, please u...
# 1                                                NaN
# 2                                                NaN
# 3  I feel burn out already for the upcoming two w...
# 4  The labs should be less challenging and more o...
#
#                                       working_detail  \
# 0  What are some things that's working well for y...
# 1  Everything is going great other than the flip ...
# 2                                                NaN
# 3                                                NaN
# 4                          Class  and lab structure
#
#                                   not_working_detail  \
# 0  What are some things that's absolutely NOT wor...
# 1  I am not able to watch the recorded lectures a...
# 2                                                NaN
# 3  I'm not sure how shuffle the quiz questions ar...
# 4  Not understanding some concepts very fast has ...
#
#                                         other_detail
# 0  If you have anything else to share with the in...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
def generate_wordcloud(text, column_name):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    
    plt.figure(figsize=(8, 4))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f"Word Cloud for {column_name}", fontsize=16)
    plt.axis('off')
    plt.show()

def generate_pie_chart(counts, title):
    plt.figure(figsize=(8, 6))
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=140)
    plt.title(title)
    plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular
    plt.show()

# Loop through each column and generate word cloud
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

for column in df.columns:
    if column == 'timestamp': continue
    if column.endswith('_detail'):
        all_text = ' '.join(df[column].dropna().astype(str).tolist())
        generate_wordcloud(all_text, column)
        # summary = summarizer(all_text, max_length=50, min_length=40, do_sample=False)
        print(f"Summary of {column}:")
        # print(summary[0]['summary_text'])
    else:
        counts = df.loc[1:, column].value_counts()
        generate_pie_chart(counts, column)
# Out:
# All PyTorch model weights were used when initializing TFBartForConditionalGeneration.
#
# All the weights of TFBartForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBartForConditionalGeneration for predictions without further training.
# /Users/tkang/miniforge3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Summary of q1_detail:
# Summary of q2_detail:
# Summary of q3_detail:
# Summary of q4_detail:
# Summary of q5_detail:
# Summary of q6_detail:
# Summary of working_detail:
# Summary of not_working_detail:
# Summary of other_detail:

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/tkang/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
df_sentiment_analysis = df
def sentiment_analysis_textblob(text):
    return TextBlob(text).sentiment

# Apply sentiment analysis for each column
for column in df_sentiment_analysis.columns:
    if column.endswith('_detail'):
        print(f"\nSentiment analysis for {column} complete")
        insert_index = df_sentiment_analysis.columns.get_loc(column)
        new_column_name = f'{column}_sentiment'
        new_column_data = df_sentiment_analysis[column].apply(lambda x: sentiment_analysis_textblob(str(x)).polarity)
        df_sentiment_analysis.insert(insert_index+1, new_column_name, new_column_data)

df_sentiment_analysis
# Out:
# Sentiment analysis for q1_detail complete
#
# Sentiment analysis for q2_detail complete
#
# Sentiment analysis for q3_detail complete
#
# Sentiment analysis for q4_detail complete
#
# Sentiment analysis for q5_detail complete
#
# Sentiment analysis for q6_detail complete
#
# Sentiment analysis for working_detail complete
#
# Sentiment analysis for not_working_detail complete
#
# Sentiment analysis for other_detail complete
#              timestamp                                                 q1  \
# 0            Timestamp  Q1: How satisfied are you with the structure o...
# 1   9/21/2024 16:49:35                                            Neutral
# 2   9/21/2024 17:00:18                                       Dissatisfied
# 3   9/21/2024 17:07:21                                            Neutral
# 4   9/21/2024 18:05:19                                       Dissatisfied
# 5   9/21/2024 18:44:01                                                NaN
# 6   9/21/2024 20:51:06                                          Satisfied
# 7   9/21/2024 21:42:56                                       Dissatisfied
# 8   9/21/2024 21:58:28                                          Satisfied
# 9    9/22/2024 0:41:04                                          Satisfied
# 10   9/22/2024 0:44:42                                  Very dissatisfied
# 11   9/22/2024 8:33:03                                          Satisfied
# 12  9/22/2024 10:42:26                                            Neutral
# 13  9/22/2024 10:59:48                                            Neutral
# 14  9/22/2024 11:40:53                                          Satisfied
# 15  9/22/2024 11:58:23                                       Dissatisfied
# 16  9/22/2024 12:43:47                                       Dissatisfied
# 17  9/22/2024 13:24:25                                          Satisfied
# 18  9/22/2024 22:02:48                                            Neutral
# 19   9/23/2024 0:51:32                                            Neutral
# 20   9/23/2024 9:12:37                                          Satisfied
# 21  9/23/2024 10:32:54                                          Satisfied
# 22  9/23/2024 10:57:23                                            Neutral
# 23  9/23/2024 10:58:08                                       Dissatisfied
# 24  9/23/2024 11:01:18                                            Neutral
# 25  9/23/2024 11:02:59                                  Very dissatisfied
# 26  9/23/2024 11:28:14                                          Satisfied
# 27  9/23/2024 11:51:05                                       Dissatisfied
# 28  9/23/2024 12:19:54                                            Neutral
# 29  9/23/2024 12:50:08                                  Very dissatisfied
# 30  9/23/2024 14:21:16                                          Satisfied
# 31  9/23/2024 19:09:09                                          Satisfied
# 32  9/24/2024 10:13:52                                            Neutral
# 33  9/24/2024 10:14:22                                                NaN
# 34  9/24/2024 10:14:41                                     Very satisfied
# 35  9/24/2024 10:16:28                                  Very dissatisfied
# 36  9/24/2024 10:18:25                                          Satisfied
# 37  9/24/2024 10:20:18                                          Satisfied
# 38  9/24/2024 10:20:36                                          Satisfied
# 39  9/24/2024 10:25:05                                       Dissatisfied
# 40  9/24/2024 10:32:25                                            Neutral
# 41  9/24/2024 10:55:13                                       Dissatisfied
# 42  9/24/2024 11:06:11                                          Satisfied
# 43  9/24/2024 15:01:44                                            Neutral
# 44  9/24/2024 16:52:42                                          Satisfied
# 45  9/24/2024 18:06:07                                          Satisfied
# 46  9/24/2024 18:27:14                                            Neutral
# 47  9/24/2024 19:41:54                                       Dissatisfied
# 48  9/24/2024 20:09:11                                            Neutral
# 49  9/24/2024 20:17:59                                          Satisfied
# 50  9/24/2024 21:32:26                                            Neutral
# 51  9/24/2024 22:02:59                                            Neutral
#
#                                             q1_detail  q1_detail_sentiment  \
# 0   If you have anything to share for Q1, please u...             0.000000
# 1   I'm not a fan of the flipped classroom concept...             0.425000
# 2                                                 NaN             0.000000
# 3   Week 3 is quite intense. I'm okay the whole st...             0.300000
# 4   I think the fast paced is not ideal for people...            -0.125000
# 5                                                 NaN             0.000000
# 6                                                 NaN             0.000000
# 7   The introductory nature of the subjects feels ...             0.204444
# 8   Pretty good grading system and course logistic...             0.192857
# 9                                                 NaN             0.000000
# 10  Too many assignments. Don't have time to prepa...             0.033333
# 11                                                NaN             0.000000
# 12  Sequence of lecture/lab is awkward sometimes. ...            -0.200000
# 13                                                NaN             0.000000
# 14                                                NaN             0.000000
# 15  I like the structure of the blocks. My main ar...             0.166667
# 16  I feel 511 and 523 took too much time for self...             0.203922
# 17  I do wish the CL students weren't divided into...             0.550000
# 18                                                NaN             0.000000
# 19                                                NaN             0.000000
# 20  About 551 grading, the grading rubics should b...             0.117361
# 21                                                NaN             0.000000
# 22  I believe learning Python and R simultaneously...             0.119048
# 23                                                NaN             0.000000
# 24                                                NaN             0.000000
# 25  The Platforms course should have videos and th...            -0.125000
# 26                                                NaN             0.000000
# 27  Things keep changing. I was expecting this pro...             0.500000
# 28  One problem is that we usually have a lab cont...            -0.054167
# 29                                                NaN             0.000000
# 30                                                NaN             0.000000
# 31  I was surprised I ran out of time, yet I am a ...            -0.025000
# 32                                    kinda messy ngl            -0.200000
# 33                                                NaN             0.000000
# 34                                                NaN             0.000000
# 35  3 times the workload I had in another Canadian...             0.000000
# 36  Overall I think the structure makes sense. My ...             0.000000
# 37  There should be a lesser burden, less assignme...            -0.083333
# 38                                                NaN             0.000000
# 39                                                NaN             0.000000
# 40  The break between this term and next term is t...             0.000000
# 41                                                NaN             0.000000
# 42                                                NaN             0.000000
# 43                                                NaN             0.000000
# 44                                                NaN             0.000000
# 45                                                NaN             0.000000
# 46  I wish lab feedback and solutions could be pro...             0.000000
# 47  I think the use of autograders defeats the pur...             0.000000
# 48  the grading is too slow. With slow feedback we...            -0.075000
# 49                                                NaN             0.000000
# 50                                                NaN             0.000000
# 51  It is intense, as well as too much self-learni...             0.225000
#
#                                                    q2  \
# 0   Q2. How satisfied are you with the assessment ...
# 1                                      Very satisfied
# 2                                        Dissatisfied
# 3                                             Neutral
# 4                                        Dissatisfied
# 5                                                 NaN
# 6                                           Satisfied
# 7                                        Dissatisfied
# 8                                             Neutral
# 9                                           Satisfied
# 10                                     Very satisfied
# 11                                            Neutral
# 12                                            Neutral
# 13                                  Very dissatisfied
# 14                                          Satisfied
# 15                                          Satisfied
# 16                                       Dissatisfied
# 17                                          Satisfied
# 18                                       Dissatisfied
# 19                                       Dissatisfied
# 20                                     Very satisfied
# 21                                          Satisfied
# 22                                          Satisfied
# 23                                       Dissatisfied
# 24                                       Dissatisfied
# 25                                            Neutral
# 26                                          Satisfied
# 27                                          Satisfied
# 28                                          Satisfied
# 29                                            Neutral
# 30                                       Dissatisfied
# 31                                          Satisfied
# 32                                            Neutral
# 33                                                NaN
# 34                                          Satisfied
# 35                                  Very dissatisfied
# 36                                          Satisfied
# 37                                            Neutral
# 38                                            Neutral
# 39                                            Neutral
# 40                                       Dissatisfied
# 41                                       Dissatisfied
# 42                                          Satisfied
# 43                                            Neutral
# 44                                          Satisfied
# 45                                          Satisfied
# 46                                            Neutral
# 47                                     Very satisfied
# 48                                     Very satisfied
# 49                                          Satisfied
# 50                                       Dissatisfied
# 51                                            Neutral
#
#                                             q2_detail  q2_detail_sentiment  \
# 0   If you have anything to share for Q2, please u...             0.000000
# 1                                                 NaN             0.000000
# 2                                                 NaN             0.000000
# 3   For the quiz assessment structure, I don't lik...            -0.046667
# 4   The assessments should be one assessment at th...             0.000000
# 5                                                 NaN             0.000000
# 6                                                 NaN             0.000000
# 7   A fifty minute window for quizzes is too short...             0.238095
# 8   I might actually prefer no cheatsheet, since I...             0.000000
# 9                                                 NaN             0.000000
# 10  Writing cheatsheets by hand costs way too much...             0.233333
# 11  I don’t feel like the cheat sheets are very he...             0.050000
# 12                                                NaN             0.000000
# 13  I find it outrageous that a simple syntax erro...            -0.173469
# 14                                                NaN             0.000000
# 15                                                NaN             0.000000
# 16  I think overall it's well designed and can hel...             0.125000
# 17  I would've preferred getting information about...             0.250000
# 18                                                NaN             0.000000
# 19  I think assessment-wise there can be improveme...             0.211111
# 20                                                NaN             0.000000
# 21  Quiz week should not have classes or labs. It ...            -0.178571
# 22  It would be helpful if instructors could show ...             0.125000
# 23                                                NaN             0.000000
# 24  dissatisfaction comes from attaching a grade t...            -0.091518
# 25                                                NaN             0.000000
# 26                                                NaN             0.000000
# 27  But some labs are too advanced for what we rea...             0.200000
# 28                                                NaN             0.000000
# 29                                                NaN             0.000000
# 30                                                NaN             0.000000
# 31  Rather than later additional Quiz slots (on Sa...             0.000000
# 32                                             its ok             0.500000
# 33                                                NaN             0.000000
# 34  Quizzes 1 are disproportionately harder than q...            -0.112500
# 35                                    not fair at all            -0.350000
# 36                                                NaN             0.000000
# 37  Instead of cheatsheet it should be open web book.             0.000000
# 38                                                NaN             0.000000
# 39                                                NaN             0.000000
# 40  2 worksheet and 1 lab for 511 and 523 is a lit...             0.070833
# 41                                                NaN             0.000000
# 42                                                NaN             0.000000
# 43                                                NaN             0.000000
# 44                                                NaN             0.000000
# 45                                                NaN             0.000000
# 46                                                NaN             0.000000
# 47                                                NaN             0.000000
# 48                                                NaN             0.000000
# 49                                                NaN             0.000000
# 50                         open book would be better              0.250000
# 51  week 3 is too overwelming, labs , quizzes, wor...             0.000000
#
#                                                    q3  \
# 0   Q3. How satisfied are you with the Instructors...
# 1                                      Very satisfied
# 2                                             Neutral
# 3                                             Neutral
# 4                                             Neutral
# 5                                                 NaN
# 6                                           Satisfied
# 7                                             Neutral
# 8                                           Satisfied
# 9                                             Neutral
# 10                                       Dissatisfied
# 11                                            Neutral
# 12                                            Neutral
# 13                                            Neutral
# 14                                     Very satisfied
# 15                                          Satisfied
# 16                                          Satisfied
# 17                                     Very satisfied
# 18                                          Satisfied
# 19                                          Satisfied
# 20                                            Neutral
# 21                                          Satisfied
# 22                                          Satisfied
# 23                                       Dissatisfied
# 24                                          Satisfied
# 25                                     Very satisfied
# 26                                          Satisfied
# 27                                       Dissatisfied
# 28                                            Neutral
# 29                                            Neutral
# 30                                            Neutral
# 31                                          Satisfied
# 32                                            Neutral
# 33                                                NaN
# 34                                     Very satisfied
# 35                                  Very dissatisfied
# 36                                          Satisfied
# 37                                     Very satisfied
# 38                                            Neutral
# 39                                       Dissatisfied
# 40                                          Satisfied
# 41                                       Dissatisfied
# 42                                            Neutral
# 43                                            Neutral
# 44                                          Satisfied
# 45                                          Satisfied
# 46                                          Satisfied
# 47                                          Satisfied
# 48                                          Satisfied
# 49                                          Satisfied
# 50                                       Dissatisfied
# 51                                            Neutral
#
#                                             q3_detail  q3_detail_sentiment  \
# 0   If you have anything to share for Q3, please u...             0.000000
# 1                                                 NaN             0.000000
# 2                                                 NaN             0.000000
# 3   For 521, Andy is too fast and sometimes, I don...             0.382143
# 4   Instructors can rush through materials but emp...             0.062500
# 5                                                 NaN             0.000000
# 6                                                 NaN             0.000000
# 7   It is very often that the rushed nature of the...             0.092431
# 8   Perhaps the reverse lecture (523 - R Programmi...             0.283673
# 9                                                 NaN             0.000000
# 10  Instructors don't have enough experiences on t...             0.000000
# 11  I feel like in certain courses the content bei...             0.206429
# 12                                                NaN             0.000000
# 13                                                NaN             0.000000
# 14                                                NaN             0.000000
# 15  Instructors are very knowledgeable and are gre...             0.500000
# 16  I think our instructors are very supportive, t...             0.314167
# 17                                                NaN             0.000000
# 18                                                NaN             0.000000
# 19                                                NaN             0.000000
# 20  521's structure is unclear. Often times I'm lo...             0.500000
# 21                                                NaN             0.000000
# 22                                                NaN             0.000000
# 23                                                NaN             0.000000
# 24  At this point the content is signposting what ...             0.393750
# 25                                                NaN             0.000000
# 26                                                NaN             0.000000
# 27  Some lectures are just boring, difficult to fo...            -0.250000
# 28  I think sometimes we cannot cover all the cont...             0.000000
# 29  I think some professors do not properly cover ...            -0.125000
# 30                                                NaN             0.000000
# 31                                                NaN             0.000000
# 32                              depends on the course             0.000000
# 33                                                NaN             0.000000
# 34                                                NaN             0.000000
# 35  some random icliker topic never learnt before ...            -0.500000
# 36  The current version of the reverse format of d...             0.000000
# 37                                                NaN             0.000000
# 38                                                NaN             0.000000
# 39                                                NaN             0.000000
# 40  sometimes lecturers teaches too fast in the cl...             0.200000
# 41                                                NaN             0.000000
# 42  All profs are very passionate.\nTiff and Alexi...             0.578333
# 43                                                NaN             0.000000
# 44                                                NaN             0.000000
# 45                                                NaN             0.000000
# 46  I enjoy the energy and enthusiasm shared by th...             0.300000
# 47                                                NaN             0.000000
# 48                                                NaN             0.000000
# 49                                                NaN             0.000000
# 50                               The pace is too fast             0.200000
# 51  To be frank, some instructor seems to need mor...             0.350000
#
#     ... q5_detail_sentiment  \
# 0   ...            0.000000
# 1   ...            0.000000
# 2   ...            0.000000
# 3   ...            0.000000
# 4   ...            0.000000
# 5   ...            0.000000
# 6   ...            0.000000
# 7   ...            0.000000
# 8   ...            0.400000
# 9   ...            0.000000
# 10  ...           -0.400000
# 11  ...            0.042188
# 12  ...            0.000000
# 13  ...            0.000000
# 14  ...            0.000000
# 15  ...            0.000000
# 16  ...            0.211111
# 17  ...            0.200000
# 18  ...            0.000000
# 19  ...            0.000000
# 20  ...            0.000000
# 21  ...            0.221591
# 22  ...           -0.100000
# 23  ...            0.000000
# 24  ...            0.000000
# 25  ...            0.000000
# 26  ...            0.000000
# 27  ...            0.000000
# 28  ...            0.500000
# 29  ...            0.000000
# 30  ...            0.000000
# 31  ...            0.000000
# 32  ...            0.000000
# 33  ...            0.000000
# 34  ...            0.000000
# 35  ...           -0.260000
# 36  ...            0.000000
# 37  ...            0.000000
# 38  ...            0.000000
# 39  ...            0.000000
# 40  ...            0.000000
# 41  ...            0.000000
# 42  ...            0.397436
# 43  ...            0.000000
# 44  ...            0.000000
# 45  ...            0.000000
# 46  ...            0.000000
# 47  ...            0.132143
# 48  ...            0.000000
# 49  ...            0.000000
# 50  ...            0.000000
# 51  ...           -0.089286
#
#                                                    q6  \
# 0   Q6. How has balancing the course workload been...
# 1                                   Mostly Manageable
# 2                       Extremely difficult to manage
# 3                             Frequently Overwhelming
# 4                             Frequently Overwhelming
# 5                                                 NaN
# 6                              Sometimes Overwhelming
# 7                       Extremely difficult to manage
# 8                                   Mostly Manageable
# 9                       Extremely difficult to manage
# 10                            Frequently Overwhelming
# 11                            Frequently Overwhelming
# 12                                  Mostly Manageable
# 13                            Frequently Overwhelming
# 14                            Frequently Overwhelming
# 15                                  Mostly Manageable
# 16                             Sometimes Overwhelming
# 17                                  Mostly Manageable
# 18                            Frequently Overwhelming
# 19                             Sometimes Overwhelming
# 20                                  Mostly Manageable
# 21                            Frequently Overwhelming
# 22                             Sometimes Overwhelming
# 23                      Extremely difficult to manage
# 24                                  Mostly Manageable
# 25                            Frequently Overwhelming
# 26                                  Mostly Manageable
# 27                            Frequently Overwhelming
# 28                            Frequently Overwhelming
# 29                             Sometimes Overwhelming
# 30                      Extremely difficult to manage
# 31                            Frequently Overwhelming
# 32                                  Mostly Manageable
# 33                                                NaN
# 34                             Sometimes Overwhelming
# 35                      Extremely difficult to manage
# 36                                  Mostly Manageable
# 37                            Frequently Overwhelming
# 38                      Extremely difficult to manage
# 39                                  Mostly Manageable
# 40                                  Mostly Manageable
# 41                            Frequently Overwhelming
# 42                             Sometimes Overwhelming
# 43                      Extremely difficult to manage
# 44                      Extremely difficult to manage
# 45                             Sometimes Overwhelming
# 46                             Sometimes Overwhelming
# 47                             Sometimes Overwhelming
# 48                                  Mostly Manageable
# 49                                  Mostly Manageable
# 50                      Extremely difficult to manage
# 51                            Frequently Overwhelming
#
#                                             q6_detail q6_detail_sentiment  \
# 0   If you have anything to share for Q6, please u...            0.000000
# 1                                                 NaN            0.000000
# 2                                                 NaN            0.000000
# 3   I feel burn out already for the upcoming two w...            0.000000
# 4   The labs should be less challenging and more o...            0.277778
# 5                                                 NaN            0.000000
# 6                                                 NaN            0.000000
# 7   Both of this questions go hand in hand, becaus...            0.105556
# 8                                   Pretty manageable            0.250000
# 9                                                 NaN            0.000000
# 10                  The labs are too time-consuming.             0.000000
# 11  I think it’s just a lot, especially when it co...            0.166667
# 12                                                NaN            0.000000
# 13                                                NaN            0.000000
# 14                                                NaN            0.000000
# 15  I can see this becoming less manageable for me...            0.056667
# 16  I hope when the labs being designed, we could ...            0.050000
# 17                                                NaN            0.000000
# 18                                                NaN            0.000000
# 19                                                NaN            0.000000
# 20                                                NaN            0.000000
# 21  Deadlines need to be extended to Sunday night ...            0.050000
# 22                                                NaN            0.000000
# 23                                                NaN            0.000000
# 24                                                NaN            0.000000
# 25  The Platform for the exam with respect to math...           -0.500000
# 26                                                NaN            0.000000
# 27                                                NaN            0.000000
# 28                                                NaN            0.000000
# 29                                                NaN            0.000000
# 30                                                NaN            0.000000
# 31                                                NaN            0.000000
# 32                                                NaN            0.000000
# 33                                                NaN            0.000000
# 34  Week 3 is particularly overwhelming due to hav...            0.210000
# 35                                very heavy workload           -0.260000
# 36                                                NaN            0.000000
# 37                                                NaN            0.000000
# 38                                                NaN            0.000000
# 39                                                NaN            0.000000
# 40                                                NaN            0.000000
# 41                                                NaN            0.000000
# 42  Instructions for assignments can be more conci...            0.064583
# 43                                                NaN            0.000000
# 44                                                NaN            0.000000
# 45                                                NaN            0.000000
# 46  I find myself working till 10pm at night to co...            0.000000
# 47                                                NaN            0.000000
# 48                                                NaN            0.000000
# 49                                                NaN            0.000000
# 50                                                NaN            0.000000
# 51                            lighter workload please            0.000000
#
#                                        working_detail  \
# 0   What are some things that's working well for y...
# 1   Everything is going great other than the flip ...
# 2                                                 NaN
# 3                                                 NaN
# 4                           Class  and lab structure
# 5                                                 NaN
# 6                                                 NaN
# 7             pre-lectures, worksheets, lab materials
# 8            Good teacher instruction, TA instruction
# 9                                      Lecture notes.
# 10                                                NaN
# 11  I think the labs and the worksheets and their ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16            Thanks so much for being so supportive!
# 17                                                NaN
# 18                        Instructors are very caring
# 19                                                NaN
# 20  sticking to the schedules helps a lot. And the...
# 21               Course material , labs , instructors
# 22                                                NaN
# 23                                                NaN
# 24  Content so far is clear enough as being releva...
# 25                                                NaN
# 26  4 day classes. Getting a 3 day weekend! Also, ...
# 27                                   Teaching myself
# 28        I think I did learn some programming skill.
# 29  I do think the professors are trying to suppor...
# 30                                                NaN
# 31  The labs are very useful in reinforcing the sk...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36  frequent communication and availability of ins...
# 37  Lectures are very good. Tecahers and TA are he...
# 38                                                NaN
# 39                                                NaN
# 40  The teaching team is very supportive and respo...
# 41                                                NaN
# 42  Course mechanics and administrations are flexi...
# 43                                                NaN
# 44           The lecturenotes are clear and detailed.
# 45  Been able to complement lectures with the note...
# 46  I enjoy the structured learning environment al...
# 47  1. Well effective communication\n2. Strict dea...
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51  The academic coordinating team is honestly ope...
#
#     working_detail_sentiment  \
# 0                   0.227273
# 1                   0.337500
# 2                   0.000000
# 3                   0.000000
# 4                   0.000000
# 5                   0.000000
# 6                   0.000000
# 7                   0.000000
# 8                   0.700000
# 9                   0.000000
# 10                  0.000000
# 11                  0.300000
# 12                  0.000000
# 13                  0.000000
# 14                  0.000000
# 15                  0.000000
# 16                  0.341667
# 17                  0.000000
# 18                  0.200000
# 19                  0.000000
# 20                  0.200000
# 21                  0.000000
# 22                  0.000000
# 23                  0.000000
# 24                  0.150000
# 25                  0.000000
# 26                  0.200000
# 27                  0.000000
# 28                  0.000000
# 29                  0.733333
# 30                  0.000000
# 31                  0.390000
# 32                  0.000000
# 33                  0.000000
# 34                  0.000000
# 35                  0.000000
# 36                  0.100000
# 37                  0.910000
# 38                  0.000000
# 39                  0.000000
# 40                  0.491667
# 41                  0.000000
# 42                  0.400000
# 43                  0.000000
# 44                  0.250000
# 45                  0.350000
# 46                  0.366667
# 47                  0.600000
# 48                  0.000000
# 49                  0.000000
# 50                  0.000000
# 51                  0.208333
#
#                                    not_working_detail  \
# 0   What are some things that's absolutely NOT wor...
# 1   I am not able to watch the recorded lectures a...
# 2                                                 NaN
# 3   I'm not sure how shuffle the quiz questions ar...
# 4   Not understanding some concepts very fast has ...
# 5                                                 NaN
# 6                                                 NaN
# 7   Workload, lack of rest, rushed lectures, lab s...
# 8   It's not super professional seeing the frequen...
# 9                       There's no lecture recording.
# 10                                                All
# 11  I think the quizzes are kind of hit / miss. I ...
# 12                                                NaN
# 13                       Marking system is not fair.
# 14  Not consistently having Sundays fully off, whi...
# 15                                                NaN
# 16  I hope we could have some time for social and ...
# 17                                                NaN
# 18                      Cheatsheets take so much time
# 19                                                NaN
# 20                                                NaN
# 21    Timelines , deadlines to submit lab assignments
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                             Labs!
# 28                                                NaN
# 29                 Due date being at 6 pm is annoying
# 30  Labs and worksheets during 1 quiz week, handwr...
# 31  The method used for 523 (watching videos + pre...
# 32                          remove the cheatsheet pls
# 33                                                NaN
# 34  I don't appreciate the flipped teaching method...
# 35                                                NaN
# 36                                                NaN
# 37  Week 3 burden and 8 am classes can be a bit he...
# 38                                                NaN
# 39                                                NaN
# 40  two worksheet and one lab in 511 and 523 are a...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44            Lots of homework, no lecture recording.
# 45  applying some learnings, basically 551 has bee...
# 46  Maybe its just the start of the program but I ...
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51  big leap between what is covered at class and ...
#
#    not_working_detail_sentiment  \
# 0                     -0.200000
# 1                     -0.250000
# 2                      0.000000
# 3                     -0.143056
# 4                     -0.070000
# 5                      0.000000
# 6                      0.000000
# 7                      0.000000
# 8                      0.011111
# 9                      0.000000
# 10                     0.000000
# 11                     0.400000
# 12                     0.000000
# 13                    -0.350000
# 14                     0.235000
# 15                     0.000000
# 16                     0.216667
# 17                     0.000000
# 18                     0.200000
# 19                     0.000000
# 20                     0.000000
# 21                     0.000000
# 22                     0.000000
# 23                     0.000000
# 24                     0.000000
# 25                     0.000000
# 26                     0.000000
# 27                     0.000000
# 28                     0.000000
# 29                    -0.462500
# 30                     0.000000
# 31                     0.377143
# 32                     0.000000
# 33                     0.000000
# 34                    -0.250000
# 35                     0.000000
# 36                     0.000000
# 37                     0.000000
# 38                     0.000000
# 39                     0.000000
# 40                     0.006250
# 41                     0.000000
# 42                     0.000000
# 43                     0.000000
# 44                     0.000000
# 45                    -0.047222
# 46                     0.700000
# 47                     0.000000
# 48                     0.000000
# 49                     0.000000
# 50                     0.000000
# 51                     0.000000
#
#                                          other_detail other_detail_sentiment
# 0   If you have anything else to share with the in...               0.000000
# 1                                                 NaN               0.000000
# 2                                                 NaN               0.000000
# 3                                                 NaN               0.000000
# 4                                                 NaN               0.000000
# 5                                                 NaN               0.000000
# 6                                                 NaN               0.000000
# 7   While it makes sense to have divided the cohor...               0.225000
# 8   Good work! It's obvious all the professors and...               0.458333
# 9                                                 NaN               0.000000
# 10                                                NaN               0.000000
# 11  I do think that the labs and worksheets that w...               0.237500
# 12  Quality of the TA does vary a bit. Some actual...              -0.100000
# 13                                                NaN               0.000000
# 14                                                NaN               0.000000
# 15                                                NaN               0.000000
# 16                                                NaN               0.000000
# 17                                                NaN               0.000000
# 18                                                NaN               0.000000
# 19                                                NaN               0.000000
# 20                                                NaN               0.000000
# 21                                                NaN               0.000000
# 22                                                NaN               0.000000
# 23                                                NaN               0.000000
# 24                                                NaN               0.000000
# 25                                                NaN               0.000000
# 26                                                NaN               0.000000
# 27  The non verbal cue you get when you approach t...               0.000000
# 28                                                NaN               0.000000
# 29                                                NaN               0.000000
# 30                                                NaN               0.000000
# 31                                                NaN               0.000000
# 32                                                NaN               0.000000
# 33                                                NaN               0.000000
# 34  Overall I am learning a lot and enjoying the p...               0.098854
# 35                                                NaN               0.000000
# 36                                                NaN               0.000000
# 37                                                NaN               0.000000
# 38                                                NaN               0.000000
# 39                                                NaN               0.000000
# 40                                                NaN               0.000000
# 41                                                NaN               0.000000
# 42                                                NaN               0.000000
# 43                                                NaN               0.000000
# 44  I extremely hope there are lecture recording s...               0.037500
# 45           the instructors are doing very great job               1.000000
# 46                                                NaN               0.000000
# 47                                                NaN               0.000000
# 48                                                NaN               0.000000
# 49                                                NaN               0.000000
# 50                                                NaN               0.000000
# 51  if possible reset the sections for each block ...               0.000000
#
# [52 rows x 25 columns]
